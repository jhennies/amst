# %% [markdown]
# # AMST test YZ
#
# Example of usage with a Jupyter Notebook.

# %% [markdown]
# ## Alignment of dataset

# %%
# %load_ext autoreload
# %autoreload 2
from amst.amst_main import amst_align, default_amst_params

raw_folder = 'C:\\Users\\JMS\\Desktop\\AMST\\20140801_hela-wt_xy5z8nm_as_part\\raw_8bit' #  
pre_alignment_folder ='C:\\Users\\JMS\\Desktop\\AMST\\20140801_hela-wt_xy5z8nm_as_part\\tm_pre_align' # 
target_folder = 'C:\\Users\JMS\\Desktop\\AMST\\hela_res_2'
# Out:
# Running SIFT on Quadro K1100M

# %%
# Load the default parameters
params = default_amst_params()
params['n_workers'] = 2  # The default number of CPU cores is 8; set this to the number that is available
params['coarse_alignment']= 'XCORR'
params['verbose']= True
params
# Out:
# {'median_radius': 7,
#  'elastix_params': {'FixedInternalImagePixelType': 'float',
#   'MovingInternalImagePixelType': 'float',
#   'UseDirectionCosines': True,
#   'Registration': 'MultiResolutionRegistration',
#   'Interpolator': 'BSplineInterpolator',
#   'ResampleInterpolator': 'FinalBSplineInterpolator',
#   'Resampler': 'DefaultResampler',
#   'FixedImagePyramid': 'FixedRecursiveImagePyramid',
#   'MovingImagePyramid': 'MovingRecursiveImagePyramid',
#   'Optimizer': 'AdaptiveStochasticGradientDescent',
#   'Transform': 'AffineTransform',
#   'Metric': 'AdvancedMattesMutualInformation',
#   'AutomaticScalesEstimation': False,
#   'AutomaticTransformInitialization': True,
#   'HowToCombineTransforms': 'Compose',
#   'NumberOfHistogramBins': 32,
#   'ErodeMask': False,
#   'NumberOfResolutions': 3,
#   'MaximumNumberOfIterations': 200,
#   'NumberOfSpatialSamples': 2048,
#   'NewSamplesEveryIteration': True,
#   'ImageSampler': 'RandomCoordinate',
#   'BSplineInterpolationOrder': 1,
#   'FinalBSplineInterpolationOrder': 3,
#   'DefaultPixelValue': 0,
#   'WriteResultImage': True,
#   'ResultImagePixelType': 'short',
#   'ResultImageFormat': 'mhd',
#   'ImagePyramidSchedule': [8, 8, 3, 3, 1, 1],
#   'MaximumStepLength': [4, 2, 1]},
#  'coarse_alignment': 'XCORR',
#  'sift_sigma': 1.6,
#  'sift_downsample': (2, 2),
#  'n_workers': 2,
#  'n_workers_sift': 1,
#  'sift_devicetype': 'GPU',
#  'compute_range': slice(None, None, None),
#  'verbose': True,
#  'write_intermediates': False}

# %%
amst_align(raw_folder=raw_folder,
    pre_alignment_folder=pre_alignment_folder,
    target_folder=target_folder,
    **params)
# Out:
# C:\Users\JMS\Documents\Anaconda3\envs\amst_env\lib\site-packages\amst\amst_main.py:368: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   assert im_list_raw != [], 'The raw folder does not contain *.tif files. \nEnsure the raw_folder input points to the correct location.'
# C:\Users\JMS\Documents\Anaconda3\envs\amst_env\lib\site-packages\amst\amst_main.py:369: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   assert im_list_pre != [], 'The folder for the pre-alignment does not contain *.tif files. \nEnsure the pre_alignment_folder input points to the correct location.'
# batch_idx = 0
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-2.03, -0.75)
# offset = (-2.98, 3.19)
# Elastix align on slice_0000.tif
# C:\Users\JMS\Documents\Anaconda3\envs\amst_env\lib\site-packages\amst
# Found elastix version: 5.000 in 'C:\\Users\\JMS\\Documents\\Anaconda3\\envs\\amst_env\\lib\\site-packages\\amst\\elastix.exe'
# Elastix align on slice_0001.tif
# batch_idx = 2
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-2.43, 4.59)
# offset = (-2.06, 0.6)
# Elastix align on slice_0002.tif
# Elastix align on slice_0003.tif
# batch_idx = 4
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-1.5, 0.49)
# offset = (-1.02, -0.35)
# Elastix align on slice_0004.tif
# Elastix align on slice_0005.tif
# batch_idx = 6
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-0.56, 0.99)
# offset = (-0.4, 0.5800000000000001)
# Elastix align on slice_0006.tif
# Elastix align on slice_0007.tif
# batch_idx = 8
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.01, -1.49)
# offset = (-0.64, 0.17)
# Elastix align on slice_0008.tif
# Elastix align on slice_0009.tif
# batch_idx = 10
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.2, 1.45)
# offset = (0.79, -2.24)
# Elastix align on slice_0010.tif
# Elastix align on slice_0011.tif
# batch_idx = 12
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.07, -0.32)
# offset = (-1.1, -5.66)
# Elastix align on slice_0012.tif
# Elastix align on slice_0013.tif
# batch_idx = 14
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-2.31, -4.94)
# offset = (1.79, -3.19)
# Elastix align on slice_0014.tif
# Elastix align on slice_0015.tif
# batch_idx = 16
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.98, -1.65)
# offset = (0.84, -1.07)
# Elastix align on slice_0016.tif
# Elastix align on slice_0017.tif
# batch_idx = 18
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.6799999999999999, 0.0)
# offset = (1.31, 0.75)
# Elastix align on slice_0018.tif
# Elastix align on slice_0019.tif
# batch_idx = 20
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.54, 1.85)
# offset = (1.59, 3.18)
# Elastix align on slice_0020.tif
# Elastix align on slice_0021.tif
# batch_idx = 22
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.22, -6.25)
# offset = (2.2800000000000002, -5.29)
# Elastix align on slice_0022.tif
# Elastix align on slice_0023.tif
# batch_idx = 24
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.1, -4.47)
# offset = (2.15, -4.45)
# Elastix align on slice_0024.tif
# Elastix align on slice_0025.tif
# batch_idx = 26
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.15, -3.97)
# offset = (1.98, -3.45)
# Elastix align on slice_0026.tif
# Elastix align on slice_0027.tif
# batch_idx = 28
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.51, -2.52)
# offset = (2.56, -4.83)
# Elastix align on slice_0028.tif
# Elastix align on slice_0029.tif
# batch_idx = 30
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.81, -4.01)
# offset = (1.6099999999999999, -3.69)
# Elastix align on slice_0030.tif
# Elastix align on slice_0031.tif
# batch_idx = 32
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.3900000000000001, -3.3)
# offset = (1.87, -3.14)
# Elastix align on slice_0032.tif
# Elastix align on slice_0033.tif
# batch_idx = 34
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.88, -0.95)
# offset = (2.49, -5.58)
# Elastix align on slice_0034.tif
# Elastix align on slice_0035.tif
# batch_idx = 36
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.75, -4.97)
# offset = (1.38, -4.49)
# Elastix align on slice_0036.tif
# Elastix align on slice_0037.tif
# batch_idx = 38
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.54, -3.82)
# offset = (1.59, -3.55)
# Elastix align on slice_0038.tif
# Elastix align on slice_0039.tif
# batch_idx = 40
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.53, -3.06)
# offset = (1.47, -2.26)
# Elastix align on slice_0040.tif
# Elastix align on slice_0041.tif
# batch_idx = 42
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.04, -6.74)
# offset = (1.26, -6.2)
# Elastix align on slice_0042.tif
# Elastix align on slice_0043.tif
# batch_idx = 44
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.27, 11.09)
# offset = (1.29, -9.03)
# Elastix align on slice_0044.tif
# Elastix align on slice_0045.tif
# batch_idx = 46
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-0.14, -8.65)
# offset = (-0.5900000000000001, -9.79)
# Elastix align on slice_0046.tif
# Elastix align on slice_0047.tif
# batch_idx = 48
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-1.0, -10.11)
# offset = (-0.95, -9.83)
# Elastix align on slice_0048.tif
# Elastix align on slice_0049.tif
# batch_idx = 50
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-1.06, -10.1)
# offset = (1.58, -3.37)
# Elastix align on slice_0050.tif
# Elastix align on slice_0051.tif
# batch_idx = 52
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.03, -2.85)
# offset = (0.47, -2.64)
# Elastix align on slice_0052.tif
# Elastix align on slice_0053.tif
# batch_idx = 54
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.13, -2.69)
# offset = (-0.17, -2.84)
# Elastix align on slice_0054.tif
# Elastix align on slice_0055.tif
# batch_idx = 56
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-0.56, -2.82)
# offset = (-0.11, -3.46)
# Elastix align on slice_0056.tif
# Elastix align on slice_0057.tif
# batch_idx = 58
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.78, -4.12)
# offset = (1.5, -3.56)
# Elastix align on slice_0058.tif
# Elastix align on slice_0059.tif
# batch_idx = 60
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.22, -3.78)
# offset = (0.76, -3.65)
# Elastix align on slice_0060.tif
# Elastix align on slice_0061.tif
# batch_idx = 62
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.61, -4.16)
# offset = (0.9299999999999999, -4.1)
# Elastix align on slice_0062.tif
# Elastix align on slice_0063.tif
# batch_idx = 64
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.3, -5.1)
# offset = (1.57, -5.0)
# Elastix align on slice_0064.tif
# Elastix align on slice_0065.tif
# batch_idx = 66
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.18, -5.3)
# offset = (1.45, -5.36)
# Elastix align on slice_0066.tif
# Elastix align on slice_0067.tif
# batch_idx = 68
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.37, -6.25)
# offset = (1.23, -6.32)
# Elastix align on slice_0068.tif
# Elastix align on slice_0069.tif
# batch_idx = 70
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (3.22, -5.03)
# offset = (2.48, -4.88)
# Elastix align on slice_0070.tif
# Elastix align on slice_0071.tif
# batch_idx = 72
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.16, -4.79)
# offset = (0.6799999999999999, -8.91)
# Elastix align on slice_0072.tif
# Elastix align on slice_0073.tif
# batch_idx = 74
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-1.07, -9.83)
# offset = (-1.27, -10.93)
# Elastix align on slice_0074.tif
# Elastix align on slice_0075.tif
# batch_idx = 76
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-1.85, -12.02)
# offset = (-2.17, -13.46)
# Elastix align on slice_0076.tif
# Elastix align on slice_0077.tif
# batch_idx = 78
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-2.5, -14.12)
# offset = (2.97, -1.29)
# Elastix align on slice_0078.tif
# Elastix align on slice_0079.tif
# batch_idx = 80
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.84, -1.01)
# offset = (1.79, -0.95)
# Elastix align on slice_0080.tif
# Elastix align on slice_0081.tif
# batch_idx = 82
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (1.43, -1.19)
# offset = (1.15, -1.32)
# Elastix align on slice_0082.tif
# Elastix align on slice_0083.tif
# batch_idx = 84
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (0.62, -2.95)
# offset = (2.9, -0.87)
# Elastix align on slice_0084.tif
# Elastix align on slice_0085.tif
# batch_idx = 86
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.18, -3.71)
# offset = (2.49, -5.92)
# Elastix align on slice_0086.tif
# Elastix align on slice_0087.tif
# batch_idx = 88
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (2.2, -8.44)
# offset = (4.19, 0.83)
# Elastix align on slice_0088.tif
# Elastix align on slice_0089.tif
# batch_idx = 90
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (3.59, -1.3599999999999999)
# offset = (3.52, -3.99)
# Elastix align on slice_0090.tif
# Elastix align on slice_0091.tif
# batch_idx = 92
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (3.76, -5.62)
# offset = (4.16, -0.41)
# Elastix align on slice_0092.tif
# Elastix align on slice_0093.tif
# batch_idx = 94
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (3.45, -1.3900000000000001)
# offset = (0.51, -6.0)
# Elastix align on slice_0094.tif
# Elastix align on slice_0095.tif
# batch_idx = 96
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-0.94, -8.78)
# offset = (-1.75, -12.54)
# Elastix align on slice_0096.tif
# Elastix align on slice_0097.tif
# batch_idx = 98
# Generating median smoothed templates...
# Coarse alignment by translation done with cross correlation.
# offset = (-2.29, -15.38)
# offset = (4.21, 3.46)
# Elastix align on slice_0098.tif
# Elastix align on slice_0099.tif

# %% [markdown]
# ## Evaluating the alignments

# %%
import os
import numpy as np
import glob
from multiprocessing import Pool
from tifffile import imread, imsave
from silx.image import sift
from vigra.filters import gaussianSmoothing
import pickle
from amst.amst_main import xcorr
from matplotlib import pyplot as plt


def _evaluate_alignment_with_sift(im_0, im_1, areas, sigma=1.):
    print(im_0)

    im_0 = imread(im_0)
    im_1 = imread(im_1)

    if im_0.dtype == 'uint16':
        im_0 = (im_0 / (65536 / 255)).astype('uint8')
    if im_1.dtype == 'uint16':
        im_1 = (im_1 / (65536 / 255)).astype('uint8')

    im_0 = gaussianSmoothing(im_0, sigma)
    im_1 = gaussianSmoothing(im_1, sigma)

    offset = []

    for area in areas:

        crop_0 = im_0[area]
        crop_1 = im_1[area]

        crop_0 = gaussianSmoothing(crop_0, sigma)
        crop_1 = gaussianSmoothing(crop_1, sigma)

        try:
            # Do the alignment
            #sa = sift.LinearAlign(crop_0, devicetype='GPU')
            #aligned = sa.align(crop_1, return_all=True, shift_only=True)
           
            offs = xcorr(crop_0,crop_1)
            offset.append(offs)#aligned['offset'])
            sa = None
            aligned = None

        except TypeError:
            print('Warning: The alignment failed, appending [None, None]')
            offset.append([None, None])

    return offset


def evaluate_alignment(source_folder, areas, n_workers=16, target_filepath=None, z_range=None,
                                       plot=False, sigma=1.,
                                       func=_evaluate_alignment_with_sift):
    if z_range is None:
        imlist = np.array(sorted(glob.glob(os.path.join(source_folder, '*.tif'))))
    else:
        imlist = np.array(sorted(glob.glob(os.path.join(source_folder, '*.tif'))))[z_range]

    if n_workers == 1:
        offsets = [func(imlist[idx], imlist[idx + 1], areas, sigma=sigma) for idx in
                   range(len(imlist) - 1)]

    else:

        with Pool(processes=n_workers) as p:

            tasks = [
                p.apply_async(
                    func,
                    (imlist[idx], imlist[idx + 1], areas),
                    {'sigma': sigma}
                )
                for idx in range(len(imlist) - 1)
            ]

            offsets = [task.get() for task in tasks]

    offsets = np.array(offsets)

    if plot:
        for idx in range(offsets.shape[2]):
            offset_x = np.sqrt(np.power(offsets[:, 0, idx], 2) + np.power(offsets[:, 1, idx], 2))
            print(offset_x)
            plt.plot(offset_x)

        plt.show()

    if target_filepath is not None:

        if not os.path.exists(os.path.split(target_filepath)[0]):
            print('Making directory {}'.format(os.path.split(target_filepath)[0]))
            os.mkdir(os.path.split(target_filepath)[0])

        print('Dumping to {}'.format(target_filepath))
        with open(target_filepath, mode='wb') as f:
            pickle.dump(offsets, f)


def plot_alignment_quality(source_filepath, multiple_plots=False,
                           pixel_size=None,
                           units=None,
                           xmin=None, ymin=None, xmax=None, ymax=None,
                           mode='offsets'
                           ):
    # if pixel_size is None:
    #     pixel_size = [1, 1]
    if units is None:
        units = ['px', 'px']

    with open(source_filepath, mode='rb') as f:
        offsets = np.array(pickle.load(f))

    offsets = offsets.astype('float64')
    colorlist = [
        'xkcd:azure',
        'xkcd:goldenrod'
    ]

    if mode == 'offsets':
        ind = 2
    elif mode == 'diffs':
        ind = 1

    # FIXME something is wrong
    ind = 1

    for idx in range(offsets.shape[ind]):
        if mode == 'offsets':
            offset_x = np.sqrt(np.power(offsets[:, idx, 0], 2) + np.power(offsets[:, idx, 1], 2))
        elif mode == 'diffs':
            offset_x = offsets[:, idx]

        if multiple_plots:
            plt.figure()
            
        plt.plot(
            offset_x, color=colorlist[idx]
        )
        plt.ylabel('Displacement error [{}]'.format(units[1]))
        plt.xlabel('z [{}]'.format(units[0]))

        if ymin is not None:
            plt.ylim(ymin=ymin)
        if ymax is not None:
            plt.ylim(ymax=ymax)
        if xmin is not None:
            plt.xlim(xmin=xmin)
        if xmax is not None:
            plt.xlim(xmax=xmax)

        if pixel_size is not None:
            plt.xticks(plt.xticks()[0], plt.xticks()[0] * pixel_size[0])
            plt.yticks(plt.yticks()[0], plt.yticks()[0] * pixel_size[1])
            pass


def plot_alignment_improvement(
        source_filepath, source_filepath_ref,
        pixel_size=None,
        units=None,
        xmin=None, ymin=None, xmax=None, ymax=None,
        mode='offsets'
):

    if units is None:
        units = ['px', 'px']

    with open(source_filepath, mode='rb') as f:
        offsets = np.array(pickle.load(f))

    with open(source_filepath_ref, mode='rb') as f:
        offsets_ref = np.array(pickle.load(f))

    offsets = offsets.astype('float64')
    offsets_ref = offsets_ref.astype('float64')

    colorlist = [
        'xkcd:azure',
        'xkcd:goldenrod'
    ]

    ind = 1
    for idx in range(offsets.shape[ind]):
        if mode == 'offsets':
            offset_x = np.sqrt(np.power(offsets[:, idx, 0], 2) + np.power(offsets[:, idx, 1], 2))
            offset_x_ref = np.sqrt(np.power(offsets_ref[:, idx, 0], 2) + np.power(offsets_ref[:, idx, 1], 2))
        elif mode == 'diffs':
            raise NotImplementedError

        plt.plot(
            np.abs(offset_x - offset_x_ref), color=colorlist[idx]
        )
        plt.ylabel('Displacement error [{}]'.format(units[1]))
        plt.xlabel('z [{}]'.format(units[0]))

        if ymin is not None:
            plt.ylim(ymin=ymin)
        if ymax is not None:
            plt.ylim(ymax=ymax)
        if xmin is not None:
            plt.xlim(xmin=xmin)
        if xmax is not None:
            plt.xlim(xmax=xmax)

        if pixel_size is not None:
            plt.xticks(plt.xticks()[0],plt.xticks()[0]*pixel_size[0])
            plt.yticks(plt.yticks()[0], plt.yticks()[0]*pixel_size[1])
            pass


def statistics(source_filepath, mode='offsets'):
    with open(source_filepath, mode='rb') as f:
        offsets = np.array(pickle.load(f))

    offsets = offsets.astype('float64')
    ind = 1
    for idx in range(offsets.shape[ind]):
        if mode == 'offsets':
            offset_x = np.sqrt(np.power(offsets[:, idx, 0], 2) + np.power(offsets[:, idx, 1], 2))
        elif mode == 'diffs':
            offset_x = offsets[:, idx]
        offset_x = np.nan_to_num(offset_x)
        mean = np.mean(offset_x)
        median = np.median(offset_x)
        std = np.std(offset_x)
        mx = np.max(offset_x)
        mn = np.min(offset_x)

        print('---- AREA {} ----\n'.format(idx))
        print('Mean = {}'.format(mean))
        print('Median = {}'.format(median))
        print('Std = {}'.format(std))
        print('Max = {}'.format(mx))
        print('Min = {}\n'.format(mn))

# %%
areas = [
        np.s_[357:869, 2990:3504],
        np.s_[1850:2362, 2992:3504]
    ]
z_range = np.s_[16:48]

source = target_folder
target = 'C:\\Users\JMS\\Desktop\\AMST\\offsets\\offsets_xcorr.txt'

evaluate_alignment(
            source_folder=source,
            areas=areas,
            n_workers=1,
            target_filepath=target,
            z_range=z_range,
            plot=False,
            sigma=1.6,
            func=_evaluate_alignment_with_sift
        )
# Out:
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0016.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0017.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0018.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0019.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0020.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0021.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0022.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0023.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0024.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0025.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0026.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0027.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0028.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0029.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0030.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0031.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0032.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0033.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0034.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0035.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0036.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0037.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0038.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0039.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0040.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0041.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0042.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0043.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0044.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0045.tif
# C:\Users\JMS\Desktop\AMST\hela_res_2\slice_0046.tif
# Dumping to C:\Users\JMS\Desktop\AMST\offsets\offsets_xcorr.txt

# %%
target = 'C:\\Users\JMS\\Desktop\\AMST\\offsets\\offsets_xcorr.txt'
plot_alignment_quality(
        source_filepath=target,
        multiple_plots=False,
        ymin=-0.2, ymax=5, xmin=0, xmax=None,
        pixel_size=[0.008, 5],
        units=['um', 'nm'])

# %%
statistics(target)
# Out:
# ---- AREA 0 ----
#
# Mean = 0.45857526808440147
# Median = 0.422965719651132
# Std = 0.20551826137690007
# Max = 0.9270382947861431
# Min = 0.12806248474865697
#
# ---- AREA 1 ----
#
# Mean = 0.5984526514353832
# Median = 0.5323532661682466
# Std = 0.33417626909861425
# Max = 1.3674063039199431
# Min = 0.13892443989449804

# %%
source = pre_alignment_folder
target = 'C:\\Users\JMS\\Desktop\\AMST\\offsets\\offsets_xcorr_prealign.txt'

evaluate_alignment(
            source_folder=source,
            areas=areas,
            n_workers=1,
            target_filepath=target,
            z_range=z_range,
            plot=False,
            sigma=1.6,
            func=_evaluate_alignment_with_sift
        )
# Out:
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0016.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0017.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0018.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0019.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0020.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0021.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0022.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0023.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0024.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0025.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0026.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0027.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0028.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0029.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0030.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0031.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0032.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0033.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0034.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0035.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0036.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0037.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0038.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0039.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0040.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0041.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0042.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0043.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0044.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0045.tif
# C:\Users\JMS\Desktop\AMST\20140801_hela-wt_xy5z8nm_as_part\tm_pre_align\slice_0046.tif
# Dumping to C:\Users\JMS\Desktop\AMST\offsets\offsets_xcorr_prealign.txt

# %%
target = 'C:\\Users\JMS\\Desktop\\AMST\\offsets\\offsets_xcorr_prealign.txt'
plot_alignment_quality(
        source_filepath=target,
        multiple_plots=False,
        ymin=-0.2, ymax=5, xmin=0, xmax=None,
        pixel_size=[0.008, 5],
        units=['um', 'nm'])

# %%
plot_alignment_improvement(
    source_filepath =  'C:\\Users\JMS\\Desktop\\AMST\\offsets\\offsets_xcorr.txt', 
    source_filepath_ref =  'C:\\Users\JMS\\Desktop\\AMST\\offsets\\offsets_xcorr_prealign.txt',
    pixel_size=[0.008, 5],
    units=['um', 'nm'],
    ymin=-0.2, ymax=5, xmin=0, xmax=None)
